# %%
dbutils.help()

# %%
df=spark.read.format("csv").load("/FileStore/tables/StudentData.csv")

# %%
# %sh git status

# %%
client_secret = dbutils.secrets.get(
    scope="Test-Scope",
    key="clientpsw" )

# %%
# %sh
git status

# %%
# %sh
git log --oneline --all --decorate -10

# %%
# %sh
git log --all --oneline --decorate --graph --max-count=50

# %%
# %sh
git remote -v

# %%
# %sh
git push origin DB_Dev
