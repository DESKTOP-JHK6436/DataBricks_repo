# %%
# %sh
git status

# %%
# %sh
git add "New Notebook 2026-08-11 13_09_37.ipynb"
git add "RBAC.ipynb"
git add "role back access control.ipynb"

# %%
# %sh
git status

# %%
# %sh
git add "New Notebook 2026-08-11 13_09_37.ipynb"

# %%
# %sh
git status

# %%
# %sh
git status
