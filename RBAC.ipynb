# %%
dbutils.help()

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope="Test-Scope")

# %%
dbutils.secrets.get(scope="Test-scope",key="Clientid")
dbutils.secrets.get(scope="Test-scope",key="clientpsw")

# %%
spark.conf.set(
    "fs.azure.account.auth.type.stggen2accountchenna.dfs.core.windows.net",
    "OAuth"
)

spark.conf.set(
    "fs.azure.account.oauth.provider.type.stggen2accountchenna.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)

spark.conf.set(
    "fs.azure.account.oauth2.client.id.stggen2accountchenna.dfs.core.windows.net",
    "Clientid"
)

spark.conf.set(
    "fs.azure.account.oauth2.client.secret.stggen2accountchenna.dfs.core.windows.net",
    "clientpsw")

spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.stggen2accountchenna.dfs.core.windows.net",
    "https://login.microsoftonline.com/a80b86fd-6a82-4f33-969f-49cd71f7b655/oauth2/v2.0/token"
)

# %%
df=spark.read.csv("abfss://bronze@stggen2accountchenna.dfs.core.windows.net/")
display(df)
